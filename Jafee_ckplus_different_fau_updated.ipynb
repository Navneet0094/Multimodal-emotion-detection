00000022.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S504_001_00000022.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S136_005_00000010.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S501_001_00000067.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S075_008_00000011.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S100_005_00000023.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S082_005_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S127_010_00000016.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S504_001_00000021.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S100_005_00000021.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S028_001_00000024.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S026_003_00000015.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S026_003_00000013.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S022_005_00000032.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S134_003_00000010.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S089_003_00000035.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S112_005_00000016.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S133_003_00000047.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S010_004_00000018.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S999_001_00000018.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S050_004_00000019.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S058_005_00000010.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S109_003_00000015.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S032_003_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S045_005_00000028.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S034_003_00000025.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S042_004_00000018.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S037_003_00000020.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S050_004_00000021.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S067_004_00000022.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S113_008_00000022.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S087_007_00000014.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S022_005_00000031.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S109_003_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S087_007_00000015.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S058_005_00000009.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S034_003_00000026.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S011_004_00000019.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S071_004_00000027.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S014_003_00000029.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S082_005_00000016.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S502_001_00000016.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S045_005_00000029.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S029_001_00000019.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S029_001_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S011_004_00000020.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S111_006_00000009.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S111_006_00000008.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S999_001_00000016.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S092_003_00000012.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S127_010_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S109_003_00000016.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S026_003_00000014.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S130_007_00000019.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S014_003_00000030.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S112_005_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S045_005_00000030.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S092_003_00000013.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S087_007_00000016.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S506_001_00000039.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S117_006_00000008.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S032_003_00000015.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S129_006_00000009.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S066_005_00000009.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S071_004_00000026.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S127_010_00000018.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S037_003_00000021.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S506_001_00000038.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S126_008_00000028.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S029_001_00000018.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S111_006_00000010.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S130_007_00000018.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S117_006_00000009.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S133_003_00000046.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S028_001_00000023.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S090_007_00000012.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S126_008_00000027.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S090_007_00000013.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S136_005_00000009.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S133_003_00000045.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S503_001_00000069.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S072_005_00000019.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S067_004_00000021.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S089_003_00000034.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S075_008_00000012.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S129_006_00000010.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S014_003_00000028.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S503_001_00000070.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S130_007_00000020.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S119_008_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S100_005_00000022.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S067_004_00000023.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S066_005_00000010.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S502_001_00000015.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S055_004_00000028.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S502_001_00000014.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S134_003_00000009.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S034_003_00000027.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S010_004_00000019.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S011_004_00000021.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S072_005_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S037_003_00000022.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S082_005_00000015.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S055_004_00000026.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S092_003_00000014.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S506_001_00000040.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S503_001_00000071.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S075_008_00000010.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S055_004_00000027.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S501_001_00000066.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S126_008_00000029.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S090_007_00000014.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S010_004_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S058_005_00000008.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S042_004_00000020.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S071_004_00000028.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S129_006_00000008.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S999_001_00000017.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S119_008_00000016.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S113_008_00000021.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S136_005_00000008.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S089_003_00000036.png
# /kaggle/input/datasets/shawon10/ckplus/CK+48/anger/S119_008_00000018.png

# %%
dataset_path = "//kaggle/input/datasets/navneet0094/jafee-dataset/"

print(os.listdir(dataset_path))
# Out:
# ['jaffe', 'README_FIRST.txt']

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

data = []
labels = []

emotion_map = {
    'AN':0, 'DI':1, 'FE':2,
    'HA':3, 'SA':4, 'SU':5, 'NE':6
}

dataset_path = "/kaggle/input/datasets/navneet0094/jafee-dataset/jaffe"

for img_name in os.listdir(dataset_path):

    img_path = os.path.join(dataset_path, img_name)

    try:
        # grayscale
        img = Image.open(img_path).convert('L')

        # resize to 128x128
        img = img.resize((128,128))

        img = np.array(img)

        emotion = img_name.split('.')[1][:2]
        label = emotion_map[emotion]

        data.append(img)
        labels.append(label)

    except Exception as e:
        print("Error:", img_name)

data = np.array(data)
labels = np.array(labels)

print("Data shape:", data.shape)
print("Labels:", np.unique(labels))
# Out:
# Data shape: (213, 128, 128)
# Labels: [0 1 2 3 4 5 6]

# %%
plt.figure(figsize=(12,4))

for i in range(5):

    plt.subplot(1,5,i+1)

    plt.imshow(data[i], cmap='gray')

    plt.title(labels[i])

    plt.axis('off')

plt.show()

# %%
# upper_faces = []
# middle_faces = []
# lower_faces = []

# for img in data:
#         # Upper -> Eyes + Brows
#     upper = img[25:70, :]
#     # Lower -> Mouth + Chin
#     lower = img[85:128, :]

#     upper_faces.append(upper)
#     lower_faces.append(lower)

# upper_faces = np.array(upper_faces)
# lower_faces = np.array(lower_faces)

# print(upper_faces.shape)
# print(lower_faces.shape)

# %%
upper_faces = []
middle_faces = []
lower_faces = []

for img in data:
        # Upper -> Eyes + Brows
    upper = img[30:70, :]
    # Lower -> Mouth + Chin
    lower = img[85:125, :]

    upper_faces.append(upper)
    lower_faces.append(lower)

upper_faces = np.array(upper_faces)
lower_faces = np.array(lower_faces)

print(upper_faces.shape)
print(lower_faces.shape)
# Out:
# (213, 40, 128)
# (213, 40, 128)

# %%
sample = 5

fig, ax = plt.subplots(1,3, figsize=(15,5))

ax[0].imshow(data[sample], cmap='gray')
ax[0].set_title("Original")

ax[1].imshow(upper_faces[sample], cmap='gray')
ax[1].set_title("Upper")

ax[2].imshow(lower_faces[sample], cmap='gray')
ax[2].set_title("Lower")

for a in ax:
    a.axis('off')

plt.show()

# %%
from skimage.feature import hog

# %%
def extract_hog_features(images):

    features = []

    for img in images:

        hog_features = hog(
            img,
            orientations=9,
            pixels_per_cell=(8,8),
            cells_per_block=(2,2),
            block_norm='L2-Hys'
        )

        features.append(hog_features)

    return np.array(features)

# %%
# Original Face Features
X_original = extract_hog_features(data)

# Upper Face Features
X_upper = extract_hog_features(upper_faces)

# Lower Face Features
X_lower = extract_hog_features(lower_faces)

print("\nOriginal HOG Shape:", X_original.shape)
print("Upper HOG Shape   :", X_upper.shape)
print("Lower HOG Shape   :", X_lower.shape)
# Out:
# Original HOG Shape: (213, 8100)
# Upper HOG Shape   : (213, 2160)
# Lower HOG Shape   : (213, 2160)

# %%
from sklearn.model_selection import train_test_split

from sklearn.svm import SVC

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# %%
XO_train, XO_test, y_train, y_test = train_test_split(
    X_original,
    labels,
    test_size=0.2,
    random_state=42,
    stratify=labels
)

XU_train, XU_test, _, _ = train_test_split(
    X_upper,
    labels,
    test_size=0.2,
    random_state=42,
    stratify=labels
)

XL_train, XL_test, _, _ = train_test_split(
    X_lower,
    labels,
    test_size=0.2,
    random_state=42,
    stratify=labels
)

# %%
from sklearn.preprocessing import StandardScaler

# Original
scaler_O = StandardScaler()

XO_train = scaler_O.fit_transform(XO_train)
XO_test = scaler_O.transform(XO_test)

# Upper
scaler_U = StandardScaler()

XU_train = scaler_U.fit_transform(XU_train)
XU_test = scaler_U.transform(XU_test)

# Lower
scaler_L = StandardScaler()

XL_train = scaler_L.fit_transform(XL_train)
XL_test = scaler_L.transform(XL_test)

# %%
from sklearn.svm import SVC

svm_original = SVC(kernel='linear')

svm_upper = SVC(kernel='linear')

svm_lower = SVC(kernel='linear')

# %%
svm_original.fit(XO_train, y_train)

svm_upper.fit(XU_train, y_train)

svm_lower.fit(XL_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
pred_original = svm_original.predict(XO_test)

pred_upper = svm_upper.predict(XU_test)

pred_lower = svm_lower.predict(XL_test)

# %%
acc_original = accuracy_score(y_test, pred_original)

acc_upper = accuracy_score(y_test, pred_upper)

acc_lower = accuracy_score(y_test, pred_lower)

print("Original Accuracy:", acc_original)

print("Upper Accuracy:", acc_upper)

print("Lower Accuracy:", acc_lower)
# Out:
# Original Accuracy: 0.8837209302325582
# Upper Accuracy: 0.8372093023255814
# Lower Accuracy: 0.8837209302325582

# %%
regions = ['Original', 'Upper', 'Lower']

accuracies = [
    acc_original,
    acc_upper,
    acc_lower
]

plt.figure(figsize=(8,5))

bars = plt.bar(regions, accuracies)

plt.ylabel("Accuracy")

plt.title("Region-wise FER Accuracy")

for bar in bars:

    yval = bar.get_height()

    plt.text(
        bar.get_x() + 0.1,
        yval + 0.01,
        round(yval,2)
    )

plt.ylim(0,1)

plt.show()

# %%
print("\nORIGINAL FACE\n")

print(classification_report(y_test, pred_original))

print("\nUPPER FACE\n")

print(classification_report(y_test, pred_upper))

print("\nLOWER FACE\n")

print(classification_report(y_test, pred_lower))
# Out:
# ORIGINAL FACE
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.75      1.00      0.86         6
#            2       0.80      0.57      0.67         7
#            3       1.00      1.00      1.00         6
#            4       0.83      0.83      0.83         6
#            5       0.83      0.83      0.83         6
#            6       1.00      1.00      1.00         6
#
#     accuracy                           0.88        43
#    macro avg       0.89      0.89      0.88        43
# weighted avg       0.89      0.88      0.88        43
#
#
# UPPER FACE
#
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         6
#            1       0.62      0.83      0.71         6
#            2       1.00      0.86      0.92         7
#            3       1.00      0.67      0.80         6
#            4       0.75      0.50      0.60         6
#            5       1.00      1.00      1.00         6
#            6       0.86      1.00      0.92         6
#
#     accuracy                           0.84        43
#    macro avg       0.85      0.84      0.83        43
# weighted avg       0.86      0.84      0.83        43
#
#
# LOWER FACE
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.86      1.00      0.92         6
#            2       0.83      0.71      0.77         7
#            3       1.00      1.00      1.00         6
#            4       0.83      0.83      0.83         6
#            5       0.80      0.67      0.73         6
#            6       0.86      1.00      0.92         6
#
#     accuracy                           0.88        43
#    macro avg       0.88      0.89      0.88        43
# weighted avg       0.88      0.88      0.88        43

# %%
emotion_names = [
    'Anger',
    'Disgust',
    'Fear',
    'Happy',
    'Sadness',
    'Surprise',
    'Neutral'
]

# %%
# EMOTION-WISE REGION CONTRIBUTION ANALYSIS

report_upper = classification_report(
    y_test,
    pred_upper,
    output_dict=True
)



report_lower = classification_report(
    y_test,
    pred_lower,
    output_dict=True
)

# Store analysis results
emotion_analysis = []

for i, emotion in enumerate(emotion_names):

    upper_recall = report_upper[str(i)]['recall']

    lower_recall = report_lower[str(i)]['recall']

    recall_scores = {
        'Upper': upper_recall,
        'Lower': lower_recall
    }
    best_region = max(recall_scores, key=recall_scores.get)

    emotion_analysis.append([
        emotion,
        round(upper_recall,2),
        round(lower_recall,2),
        best_region
    ])

df_emotion = pd.DataFrame(
    emotion_analysis,
    columns=[
        'Emotion',
        'Upper',
        'Lower',
        'Best Region'
    ]
)
print("\nEmotion-wise Regional Contribution Analysis\n")

print(df_emotion)
# Out:
# Emotion-wise Regional Contribution Analysis
#
#     Emotion  Upper  Lower Best Region
# 0     Anger   1.00   1.00       Upper
# 1   Disgust   0.83   1.00       Lower
# 2      Fear   0.86   0.71       Upper
# 3     Happy   0.67   1.00       Lower
# 4   Sadness   0.50   0.83       Lower
# 5  Surprise   1.00   0.67       Upper
# 6   Neutral   1.00   1.00       Upper

# %%
# fig, axes = plt.subplots(2,2, figsize=(12,10))

# # Original
# ConfusionMatrixDisplay.from_predictions(
#     y_test,
#     pred_original,
#     ax=axes[0,0],
#     cmap='Blues'
# )

# axes[0,0].set_title("Original")

# # Upper
# ConfusionMatrixDisplay.from_predictions(
#     y_test,
#     pred_upper,
#     ax=axes[0,1],
#     cmap='Blues'
# )

# axes[0,1].set_title("Upper")

# # Middle
# ConfusionMatrixDisplay.from_predictions(
#     y_test,
#     pred_middle,
#     ax=axes[1,0],
#     cmap='Blues'

# )



# axes[1,1].set_title("Lower")

# plt.tight_layout()

# plt.show()

# %% [markdown]
# ### CKPLUS 7 Emotion

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

from skimage.feature import hog

from sklearn.model_selection import train_test_split

from sklearn.svm import SVC

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

from sklearn.preprocessing import StandardScaler

# %%
data = []
labels = []

emotion_map = {
    'anger':0,
    'contempt':1,
    'disgust':2,
    'fear':3,
    'happy':4,
    'sadness':5,
    'surprise':6
}

dataset_path = "/kaggle/input/datasets/shawon10/ckplus/CK+48"

# Loop through emotion folders
for emotion_folder in os.listdir(dataset_path):

    emotion_path = os.path.join(dataset_path, emotion_folder)

    if not os.path.isdir(emotion_path):
        continue

    label = emotion_map[emotion_folder]

    # Loop through images
    for img_name in os.listdir(emotion_path):

        img_path = os.path.join(emotion_path, img_name)

        try:

            img = Image.open(img_path).convert('L')

            # Resize
            img = img.resize((128,128))

            img = np.array(img)

            data.append(img)

            labels.append(label)

        except Exception as e:

            print("Error:", img_path)

data = np.array(data)
labels = np.array(labels)

print("Data Shape:", data.shape)
print("Labels:", np.unique(labels))
# Out:
# Data Shape: (981, 128, 128)
# Labels: [0 1 2 3 4 5 6]

# %%
plt.figure(figsize=(12,4))

for i in range(5):

    plt.subplot(1,5,i+1)

    plt.imshow(data[i], cmap='gray')

    plt.title(labels[i])

    plt.axis('off')

plt.tight_layout()

plt.show()

# %%
upper_faces = []
lower_faces = []

for img in data:

    # Upper Region
    upper = img[20:60, :]

    # Lower Region
    lower = img[80:120, :]

    upper_faces.append(upper)
    lower_faces.append(lower)

upper_faces = np.array(upper_faces)
lower_faces = np.array(lower_faces)

print(upper_faces.shape)
print(lower_faces.shape)
# Out:
# (981, 40, 128)
# (981, 40, 128)

# %%
sample = 0

fig, ax = plt.subplots(1,4, figsize=(18,5))

ax[0].imshow(data[sample], cmap='gray')
ax[0].set_title("Original")

ax[1].imshow(upper_faces[sample], cmap='gray')
ax[1].set_title("Upper")

ax[3].imshow(lower_faces[sample], cmap='gray')
ax[3].set_title("Lower")

for a in ax:
    a.axis('off')

plt.tight_layout()

plt.show()

# %%
def extract_hog_features(images):

    features = []

    for img in images:

        hog_features = hog(
            img,
            orientations=9,
            pixels_per_cell=(8,8),
            cells_per_block=(2,2),
            block_norm='L2-Hys'
        )

        features.append(hog_features)

    return np.array(features)

# %%
X_original = extract_hog_features(data)

X_upper = extract_hog_features(upper_faces)

X_lower = extract_hog_features(lower_faces)

print(X_original.shape)
print(X_upper.shape)
print(X_middle.shape)
print(X_lower.shape)
# Out:
# (981, 8100)
# (981, 2160)
# (981, 2160)
# (981, 2160)

# %%
XO_train, XO_test, y_train, y_test = train_test_split(
    X_original,
    labels,
    test_size=0.3,
    random_state=42,
    stratify=labels
)

XU_train, XU_test, _, _ = train_test_split(
    X_upper,
    labels,
    test_size=0.3,
    random_state=42,
    stratify=labels
)


XL_train, XL_test, _, _ = train_test_split(
    X_lower,
    labels,
    test_size=0.3,
    random_state=42,
    stratify=labels
)

# %%
scaler_O = StandardScaler()
scaler_U = StandardScaler()
scaler_L = StandardScaler()

XO_train = scaler_O.fit_transform(XO_train)
XO_test = scaler_O.transform(XO_test)

XU_train = scaler_U.fit_transform(XU_train)
XU_test = scaler_U.transform(XU_test)

XL_train = scaler_L.fit_transform(XL_train)
XL_test = scaler_L.transform(XL_test)

# %%
svm_original = SVC(kernel='linear')

svm_upper = SVC(kernel='linear')

svm_lower = SVC(kernel='linear')

svm_original.fit(XO_train, y_train)

svm_upper.fit(XU_train, y_train)

svm_lower.fit(XL_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
pred_original = svm_original.predict(XO_test)

pred_upper = svm_upper.predict(XU_test)

pred_lower = svm_lower.predict(XL_test)

# %%
acc_original = accuracy_score(y_test, pred_original)

acc_upper = accuracy_score(y_test, pred_upper)

acc_lower = accuracy_score(y_test, pred_lower)

print("Original:", acc_original)

print("Upper:", acc_upper)

print("Middle:", acc_middle)

print("Lower:", acc_lower)
# Out:
# Original: 1.0
# Upper: 0.9864406779661017
# Middle: 0.9949238578680203
# Lower: 1.0

# %%
regions = ['Original', 'Upper', 'Lower']

accuracies = [
    acc_original,
    acc_upper,
    acc_lower
]

plt.figure(figsize=(8,5))

bars = plt.bar(regions, accuracies)

plt.ylabel("Accuracy")

plt.title("CK+ Region-wise FER Accuracy")

for bar in bars:

    yval = bar.get_height()

    plt.text(
        bar.get_x() + 0.1,
        yval + 0.01,
        round(yval,2)
    )

plt.ylim(0,1.5)

plt.show()

# %%
report_upper = classification_report(
    y_test,
    pred_upper,
    output_dict=True
)

report_lower = classification_report(
    y_test,
    pred_lower,
    output_dict=True
)

emotion_analysis = []

for i, emotion in enumerate(emotion_names):


    upper_recall = report_upper[str(i)]['recall']


    lower_recall = report_lower[str(i)]['recall']

    recall_scores = {
        'Upper': upper_recall,
        'Lower': lower_recall
    }

    # Best region
    best_region = max(recall_scores, key=recall_scores.get)

    emotion_analysis.append([
        emotion,
        round(upper_recall,2),
        round(lower_recall,2),
        best_region
    ])

# Create dataframe
df_emotion = pd.DataFrame(
    emotion_analysis,
    columns=[
        'Emotion',
        'Upper',
        'Lower',
        'Best Region'
    ]
)

print("\nCK+ Emotion-wise Regional Contribution Analysis\n")

print(df_emotion)
# Out:
# CK+ Emotion-wise Regional Contribution Analysis
#
#     Emotion  Upper  Lower Best Region
# 0     Anger   1.00    1.0       Upper
# 1   Disgust   1.00    1.0       Upper
# 2      Fear   1.00    1.0       Upper
# 3     Happy   0.96    1.0       Lower
# 4   Sadness   0.95    1.0       Lower
# 5  Surprise   1.00    1.0       Upper
# 6   Neutral   1.00    1.0       Upper

# %%
#now best feature fusion technique 
#which fau is good for which model
